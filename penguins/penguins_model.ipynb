# %%
import pandas as pd
data = pd.read_csv('penguins_cleaned.csv')

# %%
from pycaret.classification import *
# Out:
# C:\Users\admin\Anaconda3\envs\pythontestcaret\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
print(data.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7                181
# 1  Adelie  Torgersen            39.5           17.4                186
# 2  Adelie  Torgersen            40.3           18.0                195
# 3  Adelie  Torgersen            36.7           19.3                193
# 4  Adelie  Torgersen            39.3           20.6                190
#
#    body_mass_g     sex
# 0         3750    male
# 1         3800  female
# 2         3250  female
# 3         3450  female
# 4         3650    male

# %%
data.isnull().sum()
data.spec
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
exp_1 = setup(data=data, target='species', log_experiment=True, experiment_name='penguins_for_lit')
# Out:
# <style  type="text/css" >
# #T_66de3_row19_col1,#T_66de3_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_66de3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66de3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_66de3_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_66de3_row0_col1" class="data row0 col1" >8595</td>
#             </tr>
#             <tr>
#                         <th id="T_66de3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_66de3_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_66de3_row1_col1" class="data row1 col1" >species</td>
#             </tr>
# ...

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_3cd9f_ th {
#           text-align: left;
# ...

# %%
rf = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_a8238_row10_col0,#T_a8238_row10_col1,#T_a8238_row10_col2,#T_a8238_row10_col3,#T_a8238_row10_col4,#T_a8238_row10_col5,#T_a8238_row10_col6{
#             background:  yellow;
#         }</style><table id="T_a8238_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a8238_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a8238_row0_col0" class="data row0 col0" >0.9583</td>
# ...

# %%
evaluate_model(rf)
# Out:
# Initializing evaluate_model()
# evaluate_model(estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=8595, verbose=0,
#                        warm_start=False), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(rf, 'penguins_rf')
# Out:
# Initializing save_model()
# save_model(model=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=8595, verbose=0,
#                        warm_start=False), model_name=penguins_rf, prep_pipe_=Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
# ...

# %%
**!mlflow ui

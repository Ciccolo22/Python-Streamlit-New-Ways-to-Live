# %%
#import libraries
import seaborn as sns
import numpy as np
import pandas as pd

# %%
tips = sns.load_dataset("tips")

# %%
#doing some quick exploratory analyses, nothing fancy....

tips.head()
tips['tip'].max()
tips['tip'].min()
tips['total_bill'].describe()
tips['sex'].unique()
tips['smoker'].unique()
tips['day'].unique()
tips['time'].unique()
tips['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
##more eda
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
#import ML library. Opting for pycaret b/c it's lowcode, quick and easy. 
from pycaret.regression import *

# %%
exp_name = setup(data = tips, numeric_features=['size'],  target = 'tip')
# Out:
# <style  type="text/css" >
# </style><table id="T_4c374786_6be1_11eb_becb_8086f2c5eb57" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c374786_6be1_11eb_becb_8086f2c5eb57level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c374786_6be1_11eb_becb_8086f2c5eb57row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4c374786_6be1_11eb_becb_8086f2c5eb57row0_col1" class="data row0 col1" >6548</td>
#             </tr>
#             <tr>
#                         <th id="T_4c374786_6be1_11eb_becb_8086f2c5eb57level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4c374786_6be1_11eb_becb_8086f2c5eb57row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
##model has been trained, castboost is my "best" option. No tuning done as I am just prototyping.
compare_models()
# Out:
# <style  type="text/css" >
#     #T_118ae352_6be2_11eb_b2bf_8086f2c5eb57 th {
#           text-align: left;
#     }    #T_118ae352_6be2_11eb_b2bf_8086f2c5eb57row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_118ae352_6be2_11eb_b2bf_8086f2c5eb57row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_118ae352_6be2_11eb_b2bf_8086f2c5eb57row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_118ae352_6be2_11eb_b2bf_8086f2c5eb57row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_118ae352_6be2_11eb_b2bf_8086f2c5eb57row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_118ae352_6be2_11eb_b2bf_8086f2c5eb57row0_col5 {
# ...

# %%
#create my catboost model. 
catmodel = create_model('catboost')
# Out:
# <style  type="text/css" >
#     #T_a67d4728_6be2_11eb_abcd_8086f2c5eb57row10_col0 {
#             background:  yellow;
#         }    #T_a67d4728_6be2_11eb_abcd_8086f2c5eb57row10_col1 {
#             background:  yellow;
#         }    #T_a67d4728_6be2_11eb_abcd_8086f2c5eb57row10_col2 {
#             background:  yellow;
#         }    #T_a67d4728_6be2_11eb_abcd_8086f2c5eb57row10_col3 {
#             background:  yellow;
#         }    #T_a67d4728_6be2_11eb_abcd_8086f2c5eb57row10_col4 {
#             background:  yellow;
#         }    #T_a67d4728_6be2_11eb_abcd_8086f2c5eb57row10_col5 {
#             background:  yellow;
# ...

# %%
#finalize model
final_mod = finalize_model(catmodel)

# %%
#save model
save_model(final_mod, 'catboost 2_10_2021')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['size'], target='tip',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='tip')),
# ...
